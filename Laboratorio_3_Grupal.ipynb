# %% [markdown]
# <a href="https://colab.research.google.com/github/EstebanS3/Laboratorios_Python/blob/Laboratorios/Laboratorio_3_Grupal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Definimos el dataframe

# %%
import pandas as pd
estudiantes=[('Ana',23,'San Jose','A'),
          ('Esteban',22,'Heredia','B'),
          ('Juan',22,'Cartago','A'),
          ('Karla',22,'Limón','A'),
          ('Ernesto',22,'Heredia','B')
          ]

df=pd.DataFrame(estudiantes,columns=['Nombre','Edad','Ciudad','Seccion'])
print(df)
# Out:
#     Nombre  Edad    Ciudad Seccion
# 0      Ana    23  San Jose       A
# 1  Esteban    22   Heredia       B
# 2     Juan    22   Cartago       A
# 3    Karla    22     Limón       A
# 4  Ernesto    22   Heredia       B

# %% [markdown]
# Creacion del Get

# %%
def getIndexes(dfObj,value):
  listOfPos=[]
  result=dfObj.isin([value])
  seriesObj=result.any()
  columnNames=list(seriesObj[seriesObj==True].index)

  for col in columnNames:
    rows=list(result[col][result[col]==True].index)

    for row in rows:
      listOfPos.append((row,col))

  return listOfPos

# %% [markdown]
# Prueba Get

# %%
listOfPositions= getIndexes(df, 'A')
print('Index positions of 22 in Dataframe : ')
for i in range(len(listOfPositions)):
  print(listOfPositions[i])
# Out:
# Index positions of 22 in Dataframe :
# (0, 'Seccion')
# (2, 'Seccion')
# (3, 'Seccion')

# %% [markdown]
# Apertura de archivo

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-07df40d3-889d-4be9-8c73-4ca47cc7b1f4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-07df40d3-889d-4be9-8c73-4ca47cc7b1f4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# Librerias

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Archivo

# %%
df=pd.read_csv('/content/drug_deaths.csv')
data=pd.DataFrame(df)
print(data)
# Out:
#       Unnamed: 0       ID                    Date  DateType   Age     Sex  \
# 0              0  14-0273  06/28/2014 12:00:00 AM       1.0   NaN     NaN
# 1              1  13-0102  03/21/2013 12:00:00 AM       0.0  48.0    Male
# 2              2  16-0165  03/13/2016 12:00:00 AM       0.0  30.0  Female
# 3              3  16-0208  03/31/2016 12:00:00 AM       0.0  23.0    Male
# 4              4  13-0052  02/13/2013 12:00:00 AM       0.0  22.0    Male
# ...          ...      ...                     ...       ...   ...     ...
# 5100        5100  15-0466  09/08/2015 12:00:00 AM       1.0  43.0    Male
# 5101        5101  17-0618  07/22/2017 12:00:00 AM       1.0  21.0    Male
# 5102        5102  18-0646  08/14/2018 12:00:00 AM       0.0  30.0    Male
# 5103        5103  14-0124  03/16/2014 12:00:00 AM       0.0  33.0    Male
# 5104        5104  16-0637  09/15/2016 12:00:00 AM       0.0  33.0    Male
#
#               Race  ResidenceCity ResidenceCounty ResidenceState  ... Tramad  \
# ...

# %% [markdown]
# Reto 8:Ejecucion Grupo:Esteban E Sanchez Sanchez , Jefferson Padilla Gonzalez, Gabriel Varela Chachon

# %% [markdown]
# Primer Elemento

# %%
#Muertes de Ciudadanos Estadounidenses Masculinos
listOfPositions= getIndexes(df, 'Male')
print('Index positions: ')
for i in range(len(listOfPositions)):
  print(listOfPositions[i])
# Out:
# Index positions:
# (1, 'Sex')
# (3, 'Sex')
# (4, 'Sex')
# (5, 'Sex')
# (8, 'Sex')
# (9, 'Sex')
# (13, 'Sex')
# (14, 'Sex')
# (15, 'Sex')
# (17, 'Sex')
# (18, 'Sex')
# (19, 'Sex')
# (20, 'Sex')
# (22, 'Sex')
# (23, 'Sex')
# (25, 'Sex')
# (26, 'Sex')
# (27, 'Sex')
# (28, 'Sex')
# (29, 'Sex')
# (30, 'Sex')
# (31, 'Sex')
# (34, 'Sex')
# (35, 'Sex')
# (36, 'Sex')
# (38, 'Sex')
# (39, 'Sex')
# (40, 'Sex')
# (42, 'Sex')
# (43, 'Sex')
# (44, 'Sex')
# (46, 'Sex')
# (47, 'Sex')
# (48, 'Sex')
# (49, 'Sex')
# (51, 'Sex')
# (52, 'Sex')
# (53, 'Sex')
# (54, 'Sex')
# (55, 'Sex')
# (57, 'Sex')
# (58, 'Sex')
# (59, 'Sex')
# (60, 'Sex')
# (61, 'Sex')
# (62, 'Sex')
# (63, 'Sex')
# (64, 'Sex')
# (65, 'Sex')
# (66, 'Sex')
# (67, 'Sex')
# (68, 'Sex')
# (70, 'Sex')
# (72, 'Sex')
# (73, 'Sex')
# (75, 'Sex')
# (76, 'Sex')
# (77, 'Sex')
# (79, 'Sex')
# (80, 'Sex')
# (81, 'Sex')
# (83, 'Sex')
# (84, 'Sex')
# (85, 'Sex')
# (87, 'Sex')
# (88, 'Sex')
# (89, 'Sex')
# (90, 'Sex')
# (91, 'Sex')
# (94, 'Sex')
# ...

# %% [markdown]
# Segundo Elemento

# %%
#Muertes de Ciudadanos Estadounidenses con 30 años de Edad
listOfPositions= getIndexes(df, 30.0)
print('Index positions: ')
for i in range(len(listOfPositions)):
  print(listOfPositions[i])
# Out:
# Index positions:
# (30, 'Unnamed: 0')
# (2, 'Age')
# (49, 'Age')
# (92, 'Age')
# (98, 'Age')
# (121, 'Age')
# (122, 'Age')
# (125, 'Age')
# (170, 'Age')
# (221, 'Age')
# (238, 'Age')
# (264, 'Age')
# (270, 'Age')
# (348, 'Age')
# (363, 'Age')
# (439, 'Age')
# (478, 'Age')
# (495, 'Age')
# (574, 'Age')
# (642, 'Age')
# (694, 'Age')
# (728, 'Age')
# (730, 'Age')
# (766, 'Age')
# (819, 'Age')
# (823, 'Age')
# (842, 'Age')
# (873, 'Age')
# (908, 'Age')
# (1071, 'Age')
# (1142, 'Age')
# (1144, 'Age')
# (1167, 'Age')
# (1366, 'Age')
# (1393, 'Age')
# (1401, 'Age')
# (1410, 'Age')
# (1552, 'Age')
# (1556, 'Age')
# (1558, 'Age')
# (1576, 'Age')
# (1595, 'Age')
# (1597, 'Age')
# (1629, 'Age')
# (1631, 'Age')
# (1673, 'Age')
# (1727, 'Age')
# (1743, 'Age')
# (1826, 'Age')
# (1878, 'Age')
# (1901, 'Age')
# (1915, 'Age')
# (1933, 'Age')
# (1993, 'Age')
# (2007, 'Age')
# (2018, 'Age')
# (2020, 'Age')
# (2042, 'Age')
# (2200, 'Age')
# (2220, 'Age')
# (2222, 'Age')
# (2252, 'Age')
# (2258, 'Age')
# ...
