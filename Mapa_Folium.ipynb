# %% [markdown]
# <a href="https://colab.research.google.com/github/EstebanS3/Laboratorios_Python/blob/Laboratorios/Mapa_Folium.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Uso de la libreria folium para extraer un mapa

# %%
import folium

# %%
from folium.plugins import minimap

# %% [markdown]
# Se usa folium y guardo el mapa en la variable USA, luego uso la variable para imprimir el mapa

# %%
USA = folium.Map(location=(56.65883,-115.16678))
USA
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# Mapa del Campus Benjamin nuñez

# %%
Campus = folium.Map(location=(9.969802568454517, -84.1288831256473))
Campus
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# Poner Marca en el Mapa

# %%
from folium.plugins import MiniMap
from branca.element import Figure

popuptext= "<b>Punto Importante de la UNA<b>"

my_map = folium.Map(location=[9.97071052359151, -84.1291289162911],zoom_start=16,tiles="stamenterrain")

#ESCINF

folium.Marker(location=[9.97071052359151, -84.1291289162911],popup=popuptext,icon=folium.Icon(color="orange",icon="ok-sign")).add_to(my_map)

folium.Circle(location=[9.97071052359151, -84.1291289162911],color="purple",weight=6,fill_color="red",fill_opacity=0.5,tooltip="ESCINF").add_to(my_map)

#Centro Internacional de Política Económica para el Desarrollo Sostenible

folium.Marker(location=[9.971343409685947, -84.12717219251734],popup=popuptext,icon=folium.Icon(color="orange",icon="ok-sign")).add_to(my_map)

folium.Circle(location=[9.971343409685947, -84.12717219251734],color="purple",weight=6,fill_color="red",fill_opacity=0.5,tooltip="Centro Internacional de Política Económica para el Desarrollo Sostenible").add_to(my_map)

#Escuela de Medicina Veterinaria

folium.Marker(location=[9.977920641389941, -84.12744186651554],popup=popuptext,icon=folium.Icon(color="orange",icon="ok-sign")).add_to(my_map)

folium.Circle(location=[9.977920641389941, -84.12744186651554],color="purple",weight=6,fill_color="red",fill_opacity=0.5,tooltip="Escuela de Medicina Veterinaria").add_to(my_map)

#Centro de Investigaciones Apícolas Tropicales

folium.Marker(location=[9.972928571976162, -84.12957953032281],popup=popuptext,icon=folium.Icon(color="orange",icon="ok-sign")).add_to(my_map)

folium.Circle(location=[9.972928571976162, -84.12957953032281],color="purple",weight=6,fill_color="red",fill_opacity=0.5,tooltip="Centro de Investigaciones Apícolas Tropicales").add_to(my_map)

#Residencias Estudiantiles Benjamín Nuñez 2

folium.Marker(location=[9.969521287942056, -84.12808250014724],popup=popuptext,icon=folium.Icon(color="orange",icon="ok-sign")).add_to(my_map)

folium.Circle(location=[9.969521287942056, -84.12808250014724],color="purple",weight=6,fill_color="red",fill_opacity=0.5,tooltip="Residencias Estudiantiles Benjamín Nuñez 2").add_to(my_map)

minimap=MiniMap(tile_layer="stamenterrain",position="bottonright")

my_map.add_child(minimap)

my_map.save("C:Folium.html")
my_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...
